# %%
#| hide
from BabyBus.core import *

# %% [markdown]
# # BabyBus
#
# >

# %% [markdown]
# This file will become your README and also the index of your documentation.

# %% [markdown]
# ## Developer Guide

# %% [markdown]
# If you are new to using `nbdev` here are some useful pointers to get you started.

# %% [markdown]
# ### Install BabyBus in Development mode

# %% [markdown]
# ```sh
# # make sure BabyBus package is installed in development mode
# $ pip install -e .
#
# # make changes under nbs/ directory
# # ...
#
# # compile to have changes apply to BabyBus
# $ nbdev_prepare
# ```

# %% [markdown]
# ## Usage

# %% [markdown]
# ### Installation

# %% [markdown]
# Install latest from the GitHub [repository][repo]:
#
# ```sh
# $ pip install git+https://github.com/songwupei/BabyBus.git
# ```
#
# or from [conda][conda]
#
# ```sh
# $ conda install -c songwupei BabyBus
# ```
#
# or from [pypi][pypi]
#
#
# ```sh
# $ pip install BabyBus
# ```
#
#
# [repo]: https://github.com/songwupei/BabyBus
# [docs]: https://songwupei.github.io/BabyBus/
# [pypi]: https://pypi.org/project/BabyBus/
# [conda]: https://anaconda.org/songwupei/BabyBus

# %% [markdown]
# ### Documentation

# %% [markdown]
# Documentation can be found hosted on this GitHub [repository][repo]'s [pages][docs]. Additionally you can find package manager specific guidelines on [conda][conda] and [pypi][pypi] respectively.
#
# [repo]: https://github.com/songwupei/BabyBus
# [docs]: https://songwupei.github.io/BabyBus/
# [pypi]: https://pypi.org/project/BabyBus/
# [conda]: https://anaconda.org/songwupei/BabyBus

# %% [markdown]
# ## How to use

# %% [markdown]
# Fill me in please! Don't forget code examples:

# %%
1+1
# Out:
# 2
